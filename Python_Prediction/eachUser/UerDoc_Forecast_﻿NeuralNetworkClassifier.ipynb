# %%
import os

import time
from datetime import datetime
from calendar import Calendar

from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.cross_validation import cross_val_score
from sklearn.model_selection import train_test_split
from sklearn import preprocessing

import pandas as pd
import matplotlib.pyplot as plt
import math
import numpy as np

from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.optimizers import SGD
from keras.datasets import mnist
from keras.utils import np_utils

# %matplotlib inline

# %% [markdown]
# ## 1. TrainingSet

# %%
def check_file_path_exist(csvName):
    if not os.path.exists(os.path.dirname(csvName)):
        try:
            os.makedirs(os.path.dirname(csvName))
        except OSError as exc: # Guard against race condition
            if exc.errno != errno.EEXIST:
                raise
                
def get_CSV_FileName(csvName, FolderName):
    cwd = os.getcwd()
    csvFullName = cwd + '/' + FolderName + '/' + csvName
#     print(csvFullName)
    return csvFullName

def get_TrainingDF(trainDataFrame, trainFeature):
    return trainDataFrame[trainFeature]

def get_PeriodTrainingDF(trainDataFrame):
    trainDataFrame['query_date_month_cos'] = trainDataFrame.eval('cos(query_date_month/12)')
    trainDataFrame['query_date_month_sin'] = trainDataFrame.eval('sin(query_date_month/12)')
    trainDataFrame['query_date_day_cos'] = trainDataFrame.eval('cos(query_date_day/31)')
    trainDataFrame['query_date_day_sin'] = trainDataFrame.eval('sin(query_date_day/31)')
    trainDataFrame['query_date_weekday_cos'] = trainDataFrame.eval('cos(query_date_weekday/7)')
    trainDataFrame['query_date_weekday_sin'] = trainDataFrame.eval('sin(query_date_weekday/7)')
    return trainDataFrame

def get_NormalizedTrainingDF(trainDataFrame):
    try:
        trainDataFrame['query_date_month'] = trainDataFrame['query_date_month']/12
        trainDataFrame['query_date_day'] = trainDataFrame['query_date_day']/31
        trainDataFrame['query_date_weekday'] = trainDataFrame['query_date_weekday']/7
    except:
        print("Unexpected error:", sys.exc_info())
    return trainDataFrame

# %%
UserName = 'mPOS'
# UserName = 'CSIS-SIT3'
# UserName = 'user1'
# UserName = 'user4'

TrainingDataFolder = 'TrainingDataSets/' + UserName + '/'
csvTrainingFile = get_CSV_FileName('TrainingFeature.csv', TrainingDataFolder)

check_file_path_exist(csvTrainingFile)

trainDF = pd.read_csv(csvTrainingFile, index_col=False )
feature = [  'query_date_year' , 'query_date_month'  ,'query_date_day', 'query_date_weekday'  ]
data = pd.get_dummies(get_TrainingDF(trainDF,feature))
data = get_PeriodTrainingDF(data)
data = get_NormalizedTrainingDF(data)

docDF = pd.read_csv(csvTrainingFile, index_col=False)['doc'].value_counts(0)
docDFHead = docDF.axes[0]

# %%
data.describe()
# Out:
#        query_date_year  query_date_month  query_date_day  query_date_weekday  \
# count           1962.0       1962.000000     1962.000000         1962.000000
# mean            2017.0          0.251572        0.502894            0.487549
# std                0.0          0.058679        0.248437            0.211532
# min             2017.0          0.166667        0.032258            0.142857
# 25%             2017.0          0.250000        0.290323            0.285714
# 50%             2017.0          0.250000        0.516129            0.571429
# 75%             2017.0          0.333333        0.677419            0.714286
# max             2017.0          0.333333        1.000000            0.857143
#
#        query_date_month_cos  query_date_month_sin  query_date_day_cos  \
# count           1962.000000           1962.000000         1962.000000
# mean               0.966857              0.248499            0.849592
# std                0.014643              0.056779            0.123132
# min                0.944957              0.165896            0.540302
# 25%                0.944957              0.247404            0.779193
# 50%                0.968912              0.247404            0.869736
# 75%                0.968912              0.327195            0.958152
# max                0.986143              0.327195            0.999480
#
#        query_date_day_sin  query_date_weekday_cos  query_date_weekday_sin
# count         1962.000000             1962.000000             1962.000000
# mean             0.467030                0.863752                0.458281
# std              0.212002                0.096392                0.186124
# min              0.032252                0.654600                0.142372
# 25%              0.286261                0.755561                0.281843
# 50%              0.493517                0.841129                0.540834
# 75%              0.626784                0.959461                0.655078
# max              0.841471                0.989813                0.755975

# %%
plt.figure();
docDF[:10].plot(kind='bar')

# %%
docDF[:5]
# Out:
# FMT_POS_0310    47
# FMT_POS_0100    47
# FMT_PA_0850     47
# FMT_POS_0340    47
# FMT_POS_0270    47
# Name: doc, dtype: int64

# %% [markdown]
# ## 2. Target Set

# %%
def get_TargetDF(targetDoc, targetDocFolder):
    csvTargetFileName = '_Target.csv'
    csvTargetFile = get_CSV_FileName(targetDoc + csvTargetFileName, targetDocFolder)
    targetDF = pd.read_csv(csvTargetFile, index_col=False )
    target = get_TrainingDF(targetDF, targetDoc)
    return target

# %%
targetDoc = 'FMT_POS_190'
target = get_TargetDF(targetDoc, TrainingDataFolder)

# %% [markdown]
# ## 3. Check DataSets

# %%
def get_TrainingDataShape(trainDataFrame, targetingDataFrame):
    print('Fearture Data Size (X): ', trainDataFrame.shape, ', Target Data Size (Y): ', targetingDataFrame.shape)

# %%
get_TrainingDataShape(data, target)
# Out:
# Fearture Data Size (X):  (1962, 10) , Target Data Size (Y):  (1962,)

# %%
data.head(5)
# Out:
#    query_date_year  query_date_month  query_date_day  query_date_weekday  \
# 0             2017          0.166667        0.258065            0.428571
# 1             2017          0.166667        0.258065            0.428571
# 2             2017          0.166667        0.258065            0.428571
# 3             2017          0.166667        0.258065            0.428571
# 4             2017          0.166667        0.258065            0.428571
#
#    query_date_month_cos  query_date_month_sin  query_date_day_cos  \
# 0              0.986143              0.165896            0.966886
# 1              0.986143              0.165896            0.966886
# 2              0.986143              0.165896            0.966886
# 3              0.986143              0.165896            0.966886
# 4              0.986143              0.165896            0.966886
#
#    query_date_day_sin  query_date_weekday_cos  query_date_weekday_sin
# 0             0.25521                 0.90956                0.415572
# 1             0.25521                 0.90956                0.415572
# 2             0.25521                 0.90956                0.415572
# 3             0.25521                 0.90956                0.415572
# 4             0.25521                 0.90956                0.415572

# %%
featureHead = data.axes[1]
print(featureHead)
# Out:
# Index(['query_date_year', 'query_date_month', 'query_date_day',
#        'query_date_weekday', 'query_date_month_cos', 'query_date_month_sin',
#        'query_date_day_cos', 'query_date_day_sin', 'query_date_weekday_cos',
#        'query_date_weekday_sin'],
#       dtype='object')

# %% [markdown]
# ## 4. Classify model

# %%
def set_Training_NNClassifier(trainDataFrame, targetingDataFrame):
    batch_size = 128
    nb_classes = 2
    nb_epoch = 100
    
    X_train, X_test, y_train, y_test = train_test_split(trainDataFrame, targetingDataFrame, test_size=0.30, random_state=0)
    X_train = X_train.as_matrix()
    X_test = X_test.as_matrix()
    y_train = y_train.as_matrix()
    y_test = y_test.as_matrix()
    y_train = np_utils.to_categorical(y_train, nb_classes)
    y_test = np_utils.to_categorical(y_test, nb_classes)
    
    model = Sequential()
    model.add(Dense(output_dim=int(X_train.shape[1]-2), input_dim=X_train.shape[1], init='normal', activation='sigmoid'))
    model.add(Dense(output_dim=int(X_train.shape[1]-2), input_dim=int(X_train.shape[1]-2), init='normal', activation='sigmoid'))
    model.add(Dense(output_dim=int(X_train.shape[1]/2), input_dim=int(X_train.shape[1]-2), init='normal', activation='sigmoid'))
    model.add(Dense(output_dim=2, input_dim=int(X_train.shape[1]/2), init='normal', activation='softmax'))
    model.compile(optimizer=SGD(lr=0.05), loss='categorical_crossentropy', metrics=['accuracy'])
#     model = Sequential()
#     model.add(Dense(64, input_dim=X_train.shape[1], activation='relu'))
#     model.add(Dropout(0.5))
#     model.add(Dense(64, activation='relu'))
#     model.add(Dropout(0.5))
#     model.add(Dense(1, activation='sigmoid'))
#     model.compile(loss='binary_crossentropy', optimizer='rmsprop', metrics=['accuracy'])

    print('Model Summary: ',model.summary())
    history = model.fit(X_train, y_train, nb_epoch=nb_epoch, batch_size=batch_size, verbose=1);
    loss, accuracy = model.evaluate(X_test, y_test, verbose=1)
    
    print('Test Model Score: ',accuracy)
    print("Click Rate: ",target.sum()/len(target)*100, "%")
    return model


def set_Training_RandomForest(trainDataFrame, targetingDataFrame):
    X_train, X_test, y_train, y_test = train_test_split(trainDataFrame, targetingDataFrame, test_size=0.30, random_state=30)
    model = RandomForestClassifier(n_estimators=100, max_depth=5)
    model.fit(X_train, y_train)
    print('Test Model Score: ',model.score(X_test, y_test) )
    print('Model Parameter: ',model.get_params )
#     print('Cross Validation Score', np.mean(cross_val_score(model, X_train, y_train, cv=10)))
    print("Click Rate: ",target.sum()/len(target)*100, "%")
    return model

def set_Training_LogisticRegression(trainDataFrame, targetingDataFrame):
    X_train, X_test, y_train, y_test = train_test_split(trainDataFrame, targetingDataFrame, test_size=0.30, random_state=30)
    model = LogisticRegression()
    model.fit(X_train, y_train)
    print('Test Model Score: ',model.score(X_test, y_test) )
    print('Model Parameter: ',model.get_params )
#     print('Cross Validation Score', np.mean(cross_val_score(model, X_train, y_train, cv=10)))
    print("Click Rate: ",target.sum()/len(target)*100, "%")
    return model


def get_Date_YearMonthDay(target_year, target_month):
    month = Calendar().itermonthdates(target_year,target_month)
    allday =[day for day in month if day.month == target_month]
    return allday

def get_PredictInput(predicDate):
#     input normalized predict input
    year  = predicDate.year
    month = predicDate.month/12
    day = predicDate.day/31
    weekday = (predicDate.weekday()+1)/7
    PredictInput = [year, month, day, weekday, math.cos(month),math.sin(month),math.cos(day), \
                    math.sin(day),math.cos(weekday),math.sin(weekday)]
    return PredictInput

# %%
# model_RandomForest  = set_Training_RandomForest(data, target)
# model_LogisticRegression = set_Training_LogisticRegression(data, target)
model_NNClassifier = set_Training_NNClassifier(data, target)
# Out:
# /Users/MH/anaconda/envs/py36/lib/python3.6/site-packages/ipykernel_launcher.py:15: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(input_dim=10, activation="sigmoid", units=8, kernel_initializer="normal")`
#   from ipykernel import kernelapp as app
# /Users/MH/anaconda/envs/py36/lib/python3.6/site-packages/ipykernel_launcher.py:16: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(input_dim=8, activation="sigmoid", units=8, kernel_initializer="normal")`
#   app.launch_new_instance()
# /Users/MH/anaconda/envs/py36/lib/python3.6/site-packages/ipykernel_launcher.py:17: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(input_dim=8, activation="sigmoid", units=5, kernel_initializer="normal")`
# /Users/MH/anaconda/envs/py36/lib/python3.6/site-packages/ipykernel_launcher.py:18: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(input_dim=5, activation="softmax", units=2, kernel_initializer="normal")`
# /Users/MH/anaconda/envs/py36/lib/python3.6/site-packages/keras/models.py:826: UserWarning: The `nb_epoch` argument in `fit` has been renamed `epochs`.
#   warnings.warn('The `nb_epoch` argument in `fit` '
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_90 (Dense)             (None, 8)                 88
# _________________________________________________________________
# dense_91 (Dense)             (None, 8)                 72
# _________________________________________________________________
# dense_92 (Dense)             (None, 5)                 45
# _________________________________________________________________
# dense_93 (Dense)             (None, 2)                 12
# =================================================================
# Total params: 217.0
# Trainable params: 217
# Non-trainable params: 0.0
# _________________________________________________________________
# Model Summary:  None
# Epoch 1/100
# 1373/1373 [==============================] - 0s - loss: 0.4945 - acc: 0.9862
# Epoch 2/100
# 1373/1373 [==============================] - 0s - loss: 0.2807 - acc: 0.9862
# Epoch 3/100
# 1373/1373 [==============================] - 0s - loss: 0.1965 - acc: 0.9862
# Epoch 4/100
# 1373/1373 [==============================] - 0s - loss: 0.1554 - acc: 0.9862
# Epoch 5/100
# 1373/1373 [==============================] - 0s - loss: 0.1317 - acc: 0.9862
# Epoch 6/100
# 1373/1373 [==============================] - 0s - loss: 0.1169 - acc: 0.9862
# Epoch 7/100
# 1373/1373 [==============================] - 0s - loss: 0.1069 - acc: 0.9862
# Epoch 8/100
# 1373/1373 [==============================] - 0s - loss: 0.0997 - acc: 0.9862
# Epoch 9/100
# 1373/1373 [==============================] - 0s - loss: 0.0946 - acc: 0.9862
# Epoch 10/100
# 1373/1373 [==============================] - 0s - loss: 0.0907 - acc: 0.9862
# Epoch 11/100
# 1373/1373 [==============================] - 0s - loss: 0.0876 - acc: 0.9862
# Epoch 12/100
# 1373/1373 [==============================] - 0s - loss: 0.0853 - acc: 0.9862
# Epoch 13/100
# 1373/1373 [==============================] - 0s - loss: 0.0834 - acc: 0.9862
# Epoch 14/100
# 1373/1373 [==============================] - 0s - loss: 0.0818 - acc: 0.9862
# Epoch 15/100
# 1373/1373 [==============================] - 0s - loss: 0.0805 - acc: 0.9862
# Epoch 16/100
# 1373/1373 [==============================] - 0s - loss: 0.0795 - acc: 0.9862
# Epoch 17/100
# 1373/1373 [==============================] - 0s - loss: 0.0786 - acc: 0.9862
# Epoch 18/100
# 1373/1373 [==============================] - 0s - loss: 0.0779 - acc: 0.9862
# Epoch 19/100
# 1373/1373 [==============================] - 0s - loss: 0.0772 - acc: 0.9862
# Epoch 20/100
# 1373/1373 [==============================] - 0s - loss: 0.0767 - acc: 0.9862
# Epoch 21/100
# 1373/1373 [==============================] - 0s - loss: 0.0763 - acc: 0.9862
# Epoch 22/100
# 1373/1373 [==============================] - 0s - loss: 0.0759 - acc: 0.9862
# Epoch 23/100
# 1373/1373 [==============================] - 0s - loss: 0.0755 - acc: 0.9862
# Epoch 24/100
# 1373/1373 [==============================] - 0s - loss: 0.0730 - acc: 0.9862
# Epoch 87/100
# 1373/1373 [==============================] - 0s - loss: 0.0730 - acc: 0.9862
# Epoch 88/100
# 1373/1373 [==============================] - 0s - loss: 0.0730 - acc: 0.9862
# Epoch 89/100
# 1373/1373 [==============================] - 0s - loss: 0.0730 - acc: 0.9862
# Epoch 90/100
# 1373/1373 [==============================] - 0s - loss: 0.0730 - acc: 0.9862
# Epoch 91/100
# 1373/1373 [==============================] - 0s - loss: 0.0730 - acc: 0.9862
# Epoch 92/100
# 1373/1373 [==============================] - 0s - loss: 0.0730 - acc: 0.9862
# Epoch 93/100
# 1373/1373 [==============================] - 0s - loss: 0.0730 - acc: 0.9862
# Epoch 94/100
# 1373/1373 [==============================] - 0s - loss: 0.0730 - acc: 0.9862
# Epoch 95/100
# 1373/1373 [==============================] - 0s - loss: 0.0730 - acc: 0.9862
# Epoch 96/100
# 1373/1373 [==============================] - 0s - loss: 0.0730 - acc: 0.9862
# Epoch 97/100
# 1373/1373 [==============================] - 0s - loss: 0.0730 - acc: 0.9862
# Epoch 98/100
# 1373/1373 [==============================] - 0s - loss: 0.0730 - acc: 0.9862
# Epoch 99/100
# 1373/1373 [==============================] - 0s - loss: 0.0730 - acc: 0.9862
# Epoch 100/100
# 1373/1373 [==============================] - 0s - loss: 0.0730 - acc: 0.9862
#  32/589 [>.............................] - ETA: 6sTest Model Score:  0.984719864177
# Click Rate:  1.42711518858 %

# %% [markdown]
# ## feature selection importance

# %%
def get_FeatureImportance(model,featureName):
    importances = model.feature_importances_
    std = np.std([tree.feature_importances_ for tree in model.estimators_], axis=0)
    indices = np.argsort(importances)[::-1]
    print("Feature ranking:")
    for f in range(len(featureName)):
        print("%d. feature %d - %s (%f)" % (f + 1, indices[f], featureName[indices[f]], importances[indices[f]]))
        
def get_FeatureImportance_Boxplot(model, featureName):
    featureLenght = len(featureName)
    plt.figure()
    plt.title("Feature importances")
    plt.bar(range(featureLenght), importances[indices],
           color="r", yerr=std[indices], align="center")
    plt.xticks(range(featureLenght), indices)
    plt.xlim([-1, featureLenght])
    plt.show()


get_FeatureImportance(model_RandomForest,featureHead)
get_FeatureImportance_Boxplot(model_RandomForest,featureHead)
# Out:
# Feature ranking:
# 1. feature 7 - query_date_day_sin (0.224055)
# 2. feature 2 - query_date_day (0.220917)
# 3. feature 6 - query_date_day_cos (0.219462)
# 4. feature 3 - query_date_weekday (0.069156)
# 5. feature 8 - query_date_weekday_cos (0.067091)
# 6. feature 9 - query_date_weekday_sin (0.066586)
# 7. feature 1 - query_date_month (0.049054)
# 8. feature 4 - query_date_month_cos (0.042445)
# 9. feature 5 - query_date_month_sin (0.041234)
# 10. feature 0 - query_date_year (0.000000)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-130-f70cd82edf15> in <module>()
#      19
#      20 get_FeatureImportance(model_RandomForest,featureHead)
# ---> 21 get_FeatureImportance_Boxplot(model_RandomForest,featureHead)
#
# <ipython-input-130-f70cd82edf15> in get_FeatureImportance_Boxplot(model, featureName)
#      11     plt.figure()
#      12     plt.title("Feature importances")
# ---> 13     plt.bar(range(featureLenght), importances[indices],
#      14            color="r", yerr=std[indices], align="center")
#      15     plt.xticks(range(featureLenght), indices)
#
# NameError: name 'importances' is not defined

# %%
data.head(5)
# Out:
#    query_date_year  query_date_month  query_date_day  query_date_weekday  \
# 0             2017          0.166667        0.258065            0.428571
# 1             2017          0.166667        0.258065            0.428571
# 2             2017          0.166667        0.258065            0.428571
# 3             2017          0.166667        0.258065            0.428571
# 4             2017          0.166667        0.258065            0.428571
#
#    query_date_month_cos  query_date_month_sin  query_date_day_cos  \
# 0              0.986143              0.165896            0.966886
# 1              0.986143              0.165896            0.966886
# 2              0.986143              0.165896            0.966886
# 3              0.986143              0.165896            0.966886
# 4              0.986143              0.165896            0.966886
#
#    query_date_day_sin  query_date_weekday_cos  query_date_weekday_sin
# 0             0.25521                 0.90956                0.415572
# 1             0.25521                 0.90956                0.415572
# 2             0.25521                 0.90956                0.415572
# 3             0.25521                 0.90956                0.415572
# 4             0.25521                 0.90956                0.415572

# %%
allday = get_Date_YearMonthDay(2017,5)
PredictInput = get_PredictInput(allday[0])
print("PredictInput: ",PredictInput)
# Out:
# PredictInput:  [2017, 0.4166666666666667, 0.03225806451612903, 0.14285714285714285, 0.9144430665938302, 0.40471456356112473, 0.9994797537524555, 0.032252470276413724, 0.9898132604466151, 0.14237172979226365]

# %%
def get_PredictResult(predictModel,targetDoc, ClickDoc_Prob = .05):
    print("Predic Doc Name: " + targetDoc )
    predict_history = []
    for predic_month in range(12):
        allday = get_Date_YearMonthDay(2017,predic_month+1)
        for day in allday:
            PredictInput = get_PredictInput(day)
            doc_predict = predictModel.predict([PredictInput])
            doc_predict_proba = predictModel.predict_proba([PredictInput])
#             print(doc_predict_proba)
            if (len(doc_predict_proba[0]) > 1):
                if (doc_predict_proba[0][1] >= ClickDoc_Prob):
                    predict_history.append([targetDoc,day.strftime('%m/%d/%Y'),day.weekday()+1,doc_predict_proba[0][1]])
#                     print(day," weekday: ", day.weekday()+1)
#                     print("user feature: ", ('doc_' + targetDoc), " click prob: ", doc_predict_proba) 
    return predict_history

# %%
getpredic = get_PredictResult(model_NNClassifier, targetDoc)
getpredic[:5]
# Out:
# Predic Doc Name: FMT_POS_190
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-134-8593dcbaaf13> in <module>()
# ----> 1 getpredic = get_PredictResult(model_NNClassifier, targetDoc)
#       2 getpredic[:5]
#
# <ipython-input-133-b9719361db59> in get_PredictResult(predictModel, targetDoc, ClickDoc_Prob)
#       6         for day in allday:
#       7             PredictInput = get_PredictInput(day)
# ----> 8             doc_predict = predictModel.predict([PredictInput])
#       9             doc_predict_proba = predictModel.predict_proba([PredictInput])
#      10 #             print(doc_predict_proba)
#
# /Users/MH/anaconda/envs/py36/lib/python3.6/site-packages/keras/models.py in predict(self, x, batch_size, verbose)
#     889         if self.model is None:
#     890             self.build()
# --> 891         return self.model.predict(x, batch_size=batch_size, verbose=verbose)
#     892
#     893     def predict_on_batch(self, x):
#
# /Users/MH/anaconda/envs/py36/lib/python3.6/site-packages/keras/engine/training.py in predict(self, x, batch_size, verbose)
#    1552         x = _standardize_input_data(x, self._feed_input_names,
#    1553                                     self._feed_input_shapes,
# -> 1554                                     check_batch_axis=False)
#    1555         if self.stateful:
#    1556             if x[0].shape[0] > batch_size and x[0].shape[0] % batch_size != 0:
#
# /Users/MH/anaconda/envs/py36/lib/python3.6/site-packages/keras/engine/training.py in _standardize_input_data(data, names, shapes, check_batch_axis, exception_prefix)
#     104     for i in range(len(names)):
#     105         array = arrays[i]
# --> 106         if len(array.shape) == 1:
#     107             array = np.expand_dims(array, 1)
#     108             arrays[i] = array
#
# AttributeError: 'list' object has no attribute 'shape'

# %%
doc_predict_proba = model.predict_proba([PredictInput])
len(doc_predict_proba[0])
docDFHead[:5]
# Out:
# Index(['FMT_PA_0780', 'FMT_POS_0130', 'FMT_PA_0852', 'FMT_POS_0080',
#        'FMT_POS_0290'],
#       dtype='object')

# %%
# 1
# UserName = 'mPOS'
# UserName = 'CSIS-SIT3'
UserName = 'user1'
# UserName = 'user4'

TrainingDataFolder = 'TrainingDataSets/' + UserName + '/'
csvTrainingFile = get_CSV_FileName('TrainingFeature.csv', TrainingDataFolder)

trainDF = pd.read_csv(csvTrainingFile, index_col=False )
feature = [  'query_date_year' , 'query_date_month'  ,'query_date_day', 'query_date_weekday'  ]
data = pd.get_dummies(get_TrainingDF(trainDF,feature))
data = get_PeriodTrainingDF(data)
data = get_NormalizedTrainingDF(data)

docDFHead = pd.read_csv(csvTrainingFile, index_col=False)['doc'].value_counts(0).axes[0]
clickDocPrediction = []

for idx, targetDoc in enumerate(docDFHead):
    if(idx%10==0):
        print("Processing: {0:.2f}%".format(idx*100/len(docDFHead)))

    target = get_TargetDF(targetDoc, TrainingDataFolder)
    model  = set_Training_RandomForest(data, target)
    predictEachDoc = get_PredictResult(model_RandomForest, targetDoc)
    if (len(predictEachDoc)> 0):
        clickDocPrediction.extend(predictEachDoc)
    elif (len(predictEachDoc) == 0):
        print(targetDoc, "No click in prediction")
# Out:
# Processing: 0.00%
# Test Model Score:  0.934579439252
# Click Rate:  6.47887323944 %
# Predic Doc Name: #POLICY#
# Test Model Score:  0.96261682243
# Click Rate:  5.35211267606 %
# Predic Doc Name: ODS_FIN_0860
# Test Model Score:  0.934579439252
# Click Rate:  3.94366197183 %
# Predic Doc Name: ODS_FIN_0770
# Test Model Score:  0.981308411215
# Click Rate:  2.81690140845 %
# Predic Doc Name: ODS_FIN_0730
# Test Model Score:  0.943925233645
# Click Rate:  2.81690140845 %
# Predic Doc Name: FMT_POS_0250
# Test Model Score:  0.981308411215
# Click Rate:  2.25352112676 %
# Predic Doc Name: ODS_FIN_0830
# Test Model Score:  0.96261682243
# Click Rate:  2.25352112676 %
# Predic Doc Name: ODS_FIN_1340
# Test Model Score:  0.990654205607
# Click Rate:  1.97183098592 %
# Predic Doc Name: FMT_PA_0850
# Test Model Score:  0.971962616822
# Click Rate:  1.69014084507 %
# Predic Doc Name: FMT_POS_0380
# Test Model Score:  0.981308411215
# Click Rate:  1.69014084507 %
# Predic Doc Name: ODS_FIN_0810
# Processing: 7.41%
# Test Model Score:  1.0
# Click Rate:  1.40845070423 %
# Predic Doc Name: ODS_FIN_0750
# Test Model Score:  1.0
# Click Rate:  1.40845070423 %
# Predic Doc Name: FMT_UNB_0091
# Test Model Score:  0.990654205607
# Click Rate:  1.40845070423 %
# Predic Doc Name: FMT_POS_0160
# Test Model Score:  0.990654205607
# Click Rate:  1.40845070423 %
# Predic Doc Name: FMT_UNB_0090
# Test Model Score:  1.0
# Click Rate:  1.40845070423 %
# Predic Doc Name: ODS_POS_0840
# Test Model Score:  1.0
# Click Rate:  1.40845070423 %
# Predic Doc Name: FMT_POS_0190
# Test Model Score:  0.971962616822
# Click Rate:  1.40845070423 %
# Predic Doc Name: FMT_POS_0350
# Test Model Score:  0.971962616822
# Click Rate:  1.40845070423 %
# Predic Doc Name: ODS_POS_1010
# Test Model Score:  0.981308411215
# Click Rate:  1.40845070423 %
# Predic Doc Name: FMT_UNB_0650
# Test Model Score:  0.981308411215
# Click Rate:  1.40845070423 %
# Predic Doc Name: FMT_POS_0070
# Processing: 14.81%
# Test Model Score:  1.0
# Click Rate:  1.12676056338 %
# Predic Doc Name: FMT_POS_0180
# Test Model Score:  0.990654205607
# Click Rate:  1.12676056338 %
# Predic Doc Name: ODS_POS_1320
# Test Model Score:  0.990654205607
# Click Rate:  1.12676056338 %
# Predic Doc Name: FMT_POS_0150
# Test Model Score:  0.990654205607
# Click Rate:  1.12676056338 %
# Predic Doc Name: ODS_POS_1330
# Test Model Score:  0.990654205607
# Click Rate:  1.12676056338 %
# Predic Doc Name: ODS_POS_0430
# Test Model Score:  0.981308411215
# Click Rate:  1.12676056338 %
# Predic Doc Name: FMT_POS_0360
# Test Model Score:  0.981308411215
# Click Rate:  1.12676056338 %
# Predic Doc Name: ODS_POS_1410
# Test Model Score:  0.990654205607
# Click Rate:  1.12676056338 %
# Predic Doc Name: FMT_POS_0140
# Test Model Score:  0.971962616822
# Click Rate:  1.12676056338 %
# Predic Doc Name: FMT_UNB_0291
# Test Model Score:  0.981308411215
# Click Rate:  1.12676056338 %
# Predic Doc Name: FMT_POS_0020
# Processing: 22.22%
# Test Model Score:  0.990654205607
# Click Rate:  1.12676056338 %
# Predic Doc Name: FMT_POS_0080
# Test Model Score:  1.0
# Click Rate:  0.845070422535 %
# Predic Doc Name: FMT_POS_0470
# Test Model Score:  0.990654205607
# Click Rate:  0.845070422535 %
# Predic Doc Name: FMT_POS_0290
# Test Model Score:  0.990654205607
# Click Rate:  0.845070422535 %
# Predic Doc Name: FMT_PA_0851
# Test Model Score:  0.981308411215
# Click Rate:  0.845070422535 %
# Predic Doc Name: FMT_POS_0130
# Test Model Score:  0.990654205607
# Click Rate:  0.845070422535 %
# Predic Doc Name: ODS_FIN_0880
# Test Model Score:  0.981308411215
# Click Rate:  0.845070422535 %
# Predic Doc Name: ODS_POS_1080
# Test Model Score:  0.981308411215
# Click Rate:  0.845070422535 %
# Predic Doc Name: ODS_POS_1140
# Click Rate:  0.56338028169 %
# Predic Doc Name: ODS_POS_1260
# Test Model Score:  1.0
# Click Rate:  0.56338028169 %
# Predic Doc Name: ODS_UNB_0690
# Test Model Score:  1.0
# Click Rate:  0.281690140845 %
# Predic Doc Name: LS_INV_0010
# Test Model Score:  1.0
# Click Rate:  0.281690140845 %
# Predic Doc Name: ODS_CLM_0400
# Test Model Score:  1.0
# Click Rate:  0.281690140845 %
# Predic Doc Name: FMT_UNB_0170
# Processing: 51.85%
# Test Model Score:  1.0
# Click Rate:  0.281690140845 %
# Predic Doc Name: ODS_FIN_1150
# Test Model Score:  0.990654205607
# Click Rate:  0.281690140845 %
# Predic Doc Name: FMT_POS_0320
# FMT_POS_0320 No click in prediction
# Test Model Score:  0.990654205607
# Click Rate:  0.281690140845 %
# Predic Doc Name: ODS_UNB_0470
# ODS_UNB_0470 No click in prediction
# Test Model Score:  0.990654205607
# Click Rate:  0.281690140845 %
# Predic Doc Name: FMT_PA_0960
# FMT_PA_0960 No click in prediction
# Test Model Score:  1.0
# Click Rate:  0.281690140845 %
# Predic Doc Name: FMT_UNB_0671
# Test Model Score:  0.990654205607
# Click Rate:  0.281690140845 %
# Predic Doc Name: ODS_POS_0930
# ODS_POS_0930 No click in prediction
# Test Model Score:  0.990654205607
# Click Rate:  0.281690140845 %
# Predic Doc Name: ODS_FIN_1160
# ODS_FIN_1160 No click in prediction
# Test Model Score:  0.990654205607
# Click Rate:  0.281690140845 %
# Predic Doc Name: ODS_PA_0430
# ODS_PA_0430 No click in prediction
# Test Model Score:  0.990654205607
# Click Rate:  0.281690140845 %
# Predic Doc Name: ODS_UNB_0680
# ODS_UNB_0680 No click in prediction
# Test Model Score:  1.0
# Click Rate:  0.281690140845 %
# Predic Doc Name: ODS_POS_7080
# Processing: 59.26%
# Test Model Score:  1.0
# Click Rate:  0.281690140845 %
# Predic Doc Name: FMT_UNB_0180
# Test Model Score:  1.0
# Click Rate:  0.281690140845 %
# Predic Doc Name: ODS_CLM_0370
# Test Model Score:  1.0
# Click Rate:  0.281690140845 %
# Predic Doc Name: FMT_UNB_0660
# Test Model Score:  1.0
# Click Rate:  0.281690140845 %
# Predic Doc Name: ODS_UNB_0240
# Test Model Score:  0.990654205607
# Click Rate:  0.281690140845 %
# Predic Doc Name: ODS_POS_1580
# ODS_POS_1580 No click in prediction
# Test Model Score:  0.990654205607
# Click Rate:  0.281690140845 %
# Predic Doc Name: ODS_FIN_0790
# ODS_FIN_0790 No click in prediction
# Test Model Score:  0.990654205607
# Click Rate:  0.281690140845 %
# Predic Doc Name: FMT_CLM_0010
# Test Model Score:  1.0
# Click Rate:  0.281690140845 %
# Predic Doc Name: ODS_PA_0640_P
# Test Model Score:  1.0
# Click Rate:  0.281690140845 %
# Predic Doc Name: ODS_FIN_1020
# Test Model Score:  1.0
# Click Rate:  0.281690140845 %
# Predic Doc Name: ODS_INV_7230
# Processing: 66.67%
# Test Model Score:  0.990654205607
# Click Rate:  0.281690140845 %
# Predic Doc Name: FMT_PA_0780
# FMT_PA_0780 No click in prediction
# Test Model Score:  1.0
# Click Rate:  0.281690140845 %
# Predic Doc Name: ODS_POS_0920
# Test Model Score:  1.0
# Click Rate:  0.281690140845 %
# Predic Doc Name: ODS_PA_0691_P
# Test Model Score:  0.990654205607
# Click Rate:  0.281690140845 %
# Predic Doc Name: ODS_CLM_0571
# ODS_CLM_0571 No click in prediction
# Test Model Score:  1.0
# Click Rate:  0.281690140845 %
# Predic Doc Name: ODS_FIN_0990
# Test Model Score:  0.990654205607
# Click Rate:  0.281690140845 %
# Predic Doc Name: ODS_UNB_0261
# ODS_UNB_0261 No click in prediction
# Test Model Score:  1.0
# Click Rate:  0.281690140845 %
# Predic Doc Name: LS_UNB_0630
# Test Model Score:  1.0
# Click Rate:  0.281690140845 %
# Predic Doc Name: FMT_UNB_0441
# Test Model Score:  1.0
# Click Rate:  0.281690140845 %
# Predic Doc Name: LS_INV_0020
# Test Model Score:  1.0
# Click Rate:  0.281690140845 %
# Predic Doc Name: ODS_FIN_0762
# Processing: 74.07%
# Test Model Score:  1.0
# Click Rate:  0.281690140845 %
# Predic Doc Name: ODS_FIN_0341
# Test Model Score:  0.990654205607
# Click Rate:  0.281690140845 %
# Predic Doc Name: FMT_UNB_0363
# FMT_UNB_0363 No click in prediction
# Test Model Score:  0.990654205607
# Click Rate:  0.281690140845 %
# Predic Doc Name: FMT_UNB_0201
# FMT_UNB_0201 No click in prediction
# Test Model Score:  1.0
# Click Rate:  0.281690140845 %
# Predic Doc Name: FMT_PA_0920
# Test Model Score:  0.990654205607
# Click Rate:  0.281690140845 %
# Predic Doc Name: ODS_POS_7150
# ODS_POS_7150 No click in prediction
# Test Model Score:  1.0
# Click Rate:  0.281690140845 %
# Predic Doc Name: ODS_PA_0631_P
# Test Model Score:  0.990654205607
# Click Rate:  0.281690140845 %
# Predic Doc Name: ODS_POS_0780
# ODS_POS_0780 No click in prediction
# Test Model Score:  1.0
# Click Rate:  0.281690140845 %
# Predic Doc Name: ODS_PA_0350_P
# Test Model Score:  1.0
# Click Rate:  0.281690140845 %
# Predic Doc Name: ODS_UNB_0640
# Test Model Score:  1.0
# Click Rate:  0.281690140845 %
# Predic Doc Name: ODS_FIN_0340
# Processing: 81.48%
# Test Model Score:  0.990654205607
# Click Rate:  0.281690140845 %
# Predic Doc Name: FMT_UNB_0361
# FMT_UNB_0361 No click in prediction
# Test Model Score:  1.0
# Click Rate:  0.281690140845 %
# Predic Doc Name: LS_INV_0030
# Test Model Score:  1.0
# Click Rate:  0.281690140845 %
# Predic Doc Name: ODS_UNB_0262
# Test Model Score:  1.0
# Click Rate:  0.281690140845 %
# Predic Doc Name: ODS_INV_7100
# Test Model Score:  0.990654205607
# Click Rate:  0.281690140845 %
# Predic Doc Name: FMT_POS_0370
# FMT_POS_0370 No click in prediction
# Test Model Score:  0.990654205607
# Click Rate:  0.281690140845 %
# Predic Doc Name: ODS_UNB_0260
# ODS_UNB_0260 No click in prediction
# Test Model Score:  1.0
# Click Rate:  0.281690140845 %
# Predic Doc Name: ODS_UNB_0450
# Test Model Score:  0.990654205607
# Click Rate:  0.281690140845 %
# Predic Doc Name: ODS_POS_0950
# ODS_POS_0950 No click in prediction
# Test Model Score:  1.0
# Click Rate:  0.281690140845 %
# Predic Doc Name: FMT_PA_0710
# Test Model Score:  1.0
# Click Rate:  0.281690140845 %
# Predic Doc Name: ODS_UNB_0510
# Processing: 88.89%
# Test Model Score:  0.990654205607
# Click Rate:  0.281690140845 %
# Predic Doc Name: ODS_UNB_0221
# ODS_UNB_0221 No click in prediction
# Test Model Score:  0.990654205607
# Click Rate:  0.281690140845 %
# Predic Doc Name: FMT_PA_0740
# FMT_PA_0740 No click in prediction
# Test Model Score:  1.0
# Click Rate:  0.281690140845 %
# Predic Doc Name: ODS_POS_7130
# Test Model Score:  0.990654205607
# Click Rate:  0.281690140845 %
# Predic Doc Name: FMT_POS_7230
# FMT_POS_7230 No click in prediction
# Test Model Score:  1.0
# Click Rate:  0.281690140845 %
# Predic Doc Name: FMT_UNB_0381
# Test Model Score:  0.990654205607
# Click Rate:  0.281690140845 %
# Predic Doc Name: LS_FIN_0010
# LS_FIN_0010 No click in prediction
# Test Model Score:  1.0
# Click Rate:  0.281690140845 %
# Predic Doc Name: ODS_UNB_0611
# Test Model Score:  1.0
# Click Rate:  0.281690140845 %
# Predic Doc Name: ODS_CLM_0510
# Test Model Score:  0.990654205607
# Click Rate:  0.281690140845 %
# Predic Doc Name: ODS_PA_0641_P
# Test Model Score:  1.0
# Click Rate:  0.281690140845 %
# Predic Doc Name: FMT_POS_0030
# Processing: 96.30%
# Test Model Score:  1.0
# Click Rate:  0.281690140845 %
# Predic Doc Name: LS_FIN_0150
# Test Model Score:  1.0
# Click Rate:  0.281690140845 %
# Predic Doc Name: FMT_POS_1571
# Test Model Score:  0.990654205607
# Click Rate:  0.281690140845 %
# Predic Doc Name: ODS_POS_0880
# ODS_POS_0880 No click in prediction
# Test Model Score:  1.0
# Click Rate:  0.281690140845 %
# Predic Doc Name: ODS_POS_1350_P
# Test Model Score:  1.0
# Click Rate:  0.281690140845 %
# Predic Doc Name: FMT_UNB_0770

# %%
predicDF = pd.DataFrame(clickDocPrediction, columns=['doc', 'query_date', 'query_date_weekday', 'click rate'])
predicDF = predicDF.sort_values(by=['query_date'])

TrainingDataFolder = 'PredictionResult'
csvPreditionFile = get_CSV_FileName(UserName + '_PredictDoc_10_Feature.csv', TrainingDataFolder)
check_file_path_exist(csvPreditionFile)

predicDF.to_csv(csvPreditionFile)

# %%
predicDF.head(5)
# Out:
#                doc  query_date  query_date_weekday  click rate
# 0         #POLICY#  01/01/2017                   7    0.142504
# 2197  ODS_POS_1340  01/01/2017                   7    0.229524
# 2046  ODS_POS_7030  01/01/2017                   7    0.074395
# 2012  ODS_POS_1250  01/01/2017                   7    0.129505
# 467   ODS_FIN_0730  01/01/2017                   7    0.059444
