# %%
import pandas as pd
import numpy as np
import time
from datetime import datetime
import sys
import csv
import os
import math

# %%
def check_file_path_exist(csvName):
    if not os.path.exists(os.path.dirname(csvName)):
        try:
            os.makedirs(os.path.dirname(csvName))
        except OSError as exc: # Guard against race condition
            if exc.errno != errno.EEXIST:
                raise

# %%
cwd = os.getcwd()
TraingFolderpath = '/TrainingDataSets/'
csvTrainingFileName = 'TrainingFeature.csv'
csvTrainingFile = cwd + TraingFolderpath + csvTrainingFileName

csvTargetFileName = 'Target.csv'
csvTargetFile = cwd + TraingFolderpath + csvTargetFileName

check_file_path_exist(csvTrainingFile)
check_file_path_exist(csvTargetFile)

# %% [markdown]
# # Training set

# %%
df = pd.read_csv('prase_out.csv', 
                       skiprows=1 ,names=['username', 'query_date', 'report_name', 'doc', 'start_date', 
                                          'end_date', 'is_period','query_date_year','query_date_month','query_date_day','query_date_weekday',
                                          'doc_start_date_year', 'doc_start_date_month','doc_start_date_day','doc_start_date_weekday',
                                          'doc_end_date_year','doc_end_date_month', 'doc_end_date_day','doc_end_date_weekday'])
traingdf=df[['username', 'doc','query_date_year','query_date_month','query_date_day','query_date_weekday']]
traingdf.to_csv(csvTrainingFile)
# Out:
#       username            doc  query_date_year  query_date_month  \
# 0       001713   ODS_UNB_0460             2017                 2
# 1       calvin  ODS_PA_0500_P             2017                 2
# 2       calvin   ODS_FIN_0573             2017                 2
# 3        user1   ODS_POS_0990             2017                 2
# 4        user1   ODS_POS_0990             2017                 2
# 5        user1   ODS_POS_0990             2017                 2
# 6        user1   ODS_POS_0990             2017                 2
# 7        user1   ODS_POS_0990             2017                 2
# 8       calvin   ODS_FIN_0740             2017                 2
# 9       calvin   ODS_FIN_0741             2017                 2
# 10      calvin   ODS_FIN_0742             2017                 2
# 11      calvin   ODS_FIN_0743             2017                 2
# 12      001751   ODS_UNB_0680             2017                 2
# 13     NBJENIA   ODS_UNB_0680             2017                 2
# 14      roxana   ODS_POS_7150             2017                 2
# 15      calvin   ODS_FIN_0761             2017                 2
# 16      roxana   ODS_POS_7150             2017                 2
# 17      calvin   ODS_FIN_0783             2017                 2
# 18      calvin   ODS_FIN_0784             2017                 2
# 19      calvin   ODS_FIN_0785             2017                 2
# 20        mPOS   FMT_POS_0070             2017                 2
# 21        mPOS   FMT_POS_0080             2017                 2
# 22        mPOS   FMT_POS_0090             2017                 2
# 23        mPOS   ODS_POS_0060             2017                 2
# 24        mPOS   FMT_POS_0310             2017                 2
# 25        mPOS   FMT_POS_0100             2017                 2
# 26        mPOS   FMT_POS_0110             2017                 2
# 27        mPOS   FMT_POS_0340             2017                 2
# 28        mPOS   FMT_POS_0130             2017                 2
# 29        mPOS   FMT_POS_0470             2017                 2
# ...        ...            ...              ...               ...
# 32293     mPOS      report001             2017                 4
# 32294     mPOS      report001             2017                 4
# 32295     mPOS      report001             2017                 4
# 32296     mPOS      report001             2017                 4
# 32297     mPOS      report001             2017                 4
# 32298     mPOS      report001             2017                 4
# 32299     mPOS      report001             2017                 4
# 32300     mPOS      report001             2017                 4
# 32301     mPOS      report001             2017                 4
# 32302     mPOS      report001             2017                 4
# 32303     mPOS      report001             2017                 4
# 32304   roxana   ODS_INV_7130             2017                 4
# 32305   roxana   ODS_INV_7140             2017                 4
# 32306    user6       #POLICY#             2017                 4
# 32307     mPOS   FMT_POS_0060             2017                 4
# 32308    user6       #POLICY#             2017                 4
# 32309     mPOS   FMT_POS_0190             2017                 4
# 32310   000718   ODS_FIN_1550             2017                 4
# 32311     mPOS   FMT_UNB_0370             2017                 4
# 32312  yusiang  ODS_PA_0631_P             2017                 4
# 32313    user6       #POLICY#             2017                 4
# 32314  yusiang  ODS_PA_0631_P             2017                 4
# 32315    user4   FMT_POS_0350             2017                 4
# 32316   jessie    ODS_SC_6500             2017                 4
# 32317  yusiang  ODS_PA_0631_P             2017                 4
# 32318     mPOS   FMT_POS_0190             2017                 4
# 32319     mPOS   FMT_POS_0190             2017                 4
# 32320     mPOS   FMT_POS_0190             2017                 4
# 32321     mPOS   FMT_POS_0190             2017                 4
# 32322    user4   FMT_POS_0350             2017                 4
#
#        query_date_day  query_date_weekday
# 0                  10                   5
# 1                  10                   5
# 2                  10                   5
# 3                  10                   5
# 4                  10                   5
# 5                  10                   5
# 6                  10                   5
# 7                  10                   5
# 8                  10                   5
# 9                  10                   5
# 10                 10                   5
# 11                 10                   5
# 12                 10                   5
# 13                 10                   5
# 14                 10                   5
# 15                 10                   5
# 16                 10                   5
# 17                 10                   5
# 18                 10                   5
# 19                 10                   5
# 20                 10                   5
# 21                 10                   5
# 22                 10                   5
# 23                 10                   5
# 24                 10                   5
# 25                 10                   5
# 26                 10                   5
# 27                 10                   5
# 28                 10                   5
# 29                 10                   5
# ...               ...                 ...
# 32293              20                   4
# 32294              20                   4
# 32295              20                   4
# 32296              20                   4
# 32297              20                   4
# 32298              20                   4
# 32299              20                   4
# 32300              20                   4
# 32301              20                   4
# 32302              20                   4
# 32303              20                   4
# 32304              20                   4
# 32305              20                   4
# 32306              20                   4
# 32307              20                   4
# 32308              20                   4
# 32309              18                   2
# 32310              20                   4
# 32311              20                   4
# 32312              20                   4
# 32313              20                   4
# 32314              20                   4
# 32315              18                   2
# 32316              18                   2
# 32317              20                   4
# 32318              18                   2
# 32319              18                   2
# 32320              18                   2
# 32321              18                   2
# 32322              18                   2
#
# [32323 rows x 6 columns]

# %% [markdown]
# # Target set

# %%
each_doc = df['doc'].value_counts(0).axes[0]
doc_df = df['doc']
targetdic = {}

for idx, each_i in enumerate(each_doc):
    if(idx%50==0):
        print("Processing: {0:.2f}%".format(idx*100/len(each_doc)))
    try:
        tmp = []
        for i in range(len(doc_df)):
            if(doc_df[i] == each_i):
                tmp.append(1)
            else:
                tmp.append(0) 
        targetdic[str(each_i)] = tmp
    except:
        print("Unexpected error:", sys.exc_info())        

targetpd = pd.DataFrame(targetdic)
targetpd.to_csv(csvTargetFile)
# Out:
# Processing: 0.00%
# Processing: 8.16%
# Processing: 16.31%
# Processing: 24.47%
# Processing: 32.63%
# Processing: 40.78%
# Processing: 48.94%
# Processing: 57.10%
# Processing: 65.25%
# Processing: 73.41%
# Processing: 81.57%
# Processing: 89.72%
# Processing: 97.88%

# %%
each_doc = df['doc'].value_counts(0).axes[0]
doc_df = df['doc']
csvEachTargetFileName = '_Target.csv'

for idx, each_i in enumerate(each_doc):
    if(idx%50==0):
        print("Processing: {0:.2f}%".format(idx*100/len(each_doc)))
     
    tmp = []
    targetdic = {}
    for i in range(len(doc_df)):
        if(doc_df[i] == each_i):
            tmp.append(1)
        else:
            tmp.append(0) 
    targetdic[str(each_i)] = tmp
    targetpd = pd.DataFrame(targetdic)

    csvEachTargetFile = cwd + TraingFolderpath +str(each_i)+ csvEachTargetFileName
    check_file_path_exist(csvEachTargetFile)
    targetpd.to_csv(csvEachTargetFile)
#     try:
#         tmp = []
#         targetdic = {}
#         for i in range(len(doc_df)):
#             if(doc_df[i] == each_i):
#                 tmp.append(1)
#             else:
#                 tmp.append(0) 
#         targetdic[str(each_i)] = tmp
#         targetpd = pd.DataFrame(targetdic)
        
#         csvTargetFile = cwd + TraingFolderpath +str(each_i)+ csvTargetFileName
#         check_file_path_exist(csvTargetFileName)
#         targetpd.to_csv(csvTargetFile)
#     except:
#         print("Unexpected error:", sys.exc_info())
# Out:
# Processing: 0.00%
# Processing: 8.16%
# Processing: 16.31%
# Processing: 24.47%
# Processing: 32.63%
# Processing: 40.78%
# Processing: 48.94%
# Processing: 57.10%
# Processing: 65.25%
# Processing: 73.41%
# Processing: 81.57%
# Processing: 89.72%
# Processing: 97.88%
